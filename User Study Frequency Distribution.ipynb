# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
s1q1 = [9,10,10,8,10,10,10,8,10,9,10,10,4]
s1q2 = [3,5,4,5,6,6,7,2,5,3,4,3,4]
s1q3 = [4,0,2,2,0,5,3,0,4,0]
s1q4 = [7, 8, 8,2,4,8,6,8,7,8,8]
s1q5 = [2,6,2,2,4,5,8,3,4,6,0]
s1q6 = [6,8,6,0,2,0,6,9]
s1q7 = [8,0,2,1,0,0,3,5,6,2,3]
s1q8 = [5, 10, 7,5,7,9,4,7,8,10]

s2q1 = [9,5,9,10,8,6,10,9,10,10]
s2q2 = [8,4,6,8,8,2,8,5,10,3,7]
s2q3 = [0,2,2,0,1,3,0,2,0,6]
s2q4 = [2,7,3,2,7,6,2,10,1]
s2q5 = [4,5,4,7,7,8,3,7,9,7,4]
s2q6 = [7,7,8,9,7,2,8,9,10,0,1]
s2q7 = [3,7,0,4,4,3,1,5,2,10]
s2q8 = [9,6,4,0,10]

s3q1 = [1,4,3,0,8,6,1,7,0,5]
s3q2 = [2, 4,1,0,5,2,1,3,0,5,5]
s3q3 = [8,4,10,2,3,0,8,2]
s3q4 = [8,9,4,10,9,3,10,9,10,10,3]
s3q5 = [6,3,4,3,7,6,10,10]
s3q6 = [3,3,3,2,5,2,1,3,5]
s3q7 = [8,3,4,0,4,3,6,7,2,2,5]
s3q8 = [4,4,1,4,4,1,8,3,10]

# %%
x= np.array(s1q1)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 1 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q2)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 2 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q3)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 3 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q4)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 4 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q5)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 5 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q6)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 6 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q7)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 7 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s1q8)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 1 Question 8 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q1)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 1 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q2)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 2 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q3)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 3 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q4)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 4 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q5)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 5 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q6)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 6 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q7)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 7 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s2q8)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 2 Question 8 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q1)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 1 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q2)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 2 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q3)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 3 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q4)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 4 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q5)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 5 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q6)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 6 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q7)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 7 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x= np.array(s3q8)
plt.hist(x, range=[0,10])
sns.kdeplot(x, clip=(0.0, 10))
plt.title('Scene 3 Question 8 Response Distribution')
plt.xlabel('Response')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
